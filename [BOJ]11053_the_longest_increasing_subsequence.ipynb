# %% [markdown]
# # 가장 긴 증가하는 부분 수열
# - source : [백준 11053](https://www.acmicpc.net/problem/11053)
# - 난이도 : 골드 V
# - 분류 : 다이나믹 프로그래밍
#
# ## 문제
# - 수열 A가 주어졌을 때, 가장 긴 증가하는 부분 수열을 구하는 프로그램을 작성하시오.
#
# - 예를 들어, 수열 A = {10, 20, 10, 30, 20, 50} 인 경우에 가장 긴 증가하는 부분 수열은 A = {10, 20, 10, 30, 20, 50} 이고, 길이는 4이다.
#
# ## 입력
# - 첫째 줄에 수열 A의 크기 N (1 ≤ N ≤ 1,000)이 주어진다.
# - 둘째 줄에는 수열 A를 이루고 있는 Ai가 주어진다. (1 ≤ Ai ≤ 1,000)
#
# ## 출력
# - 첫째 줄에 수열 A의 가장 긴 증가하는 부분 수열의 길이를 출력한다.
#
# ![image-7.png](attachment:image-7.png)

# %%
n = 6
a = [10, 20, 10, 30, 20, 50]
# 출력 : 4 

dp = [1 for _ in range(n)] 

for i in range(n):
    for j in range(i): 
        if a[i] > a[j]:
            dp[i] = max(dp[i], dp[j] + 1)
            
print(dp[n-1])
print(dp)
# Out:
# 4
# [1, 2, 1, 3, 2, 4]

# %% [markdown]
#  **최종 코드**

# %%
import sys

inp = sys.stdin.readline

n = int(inp())
a = list(map(int, inp().split()))

dp = [1 for _ in range(n)] 

for i in range(n):
    for j in range(i): 
        if a[i] > a[j]:
            dp[i] = max(dp[i], dp[j] + 1)
            
print(max(dp))

# %% [markdown]
# ![image-6.png](attachment:image-6.png)
# - [코드 출처](https://animoto1.tistory.com/entry/%EB%B0%B1%EC%A4%80-11053-%EA%B0%80%EC%9E%A5-%EA%B8%B4-%EC%A6%9D%EA%B0%80%ED%95%98%EB%8A%94-%EB%B6%80%EB%B6%84-%EC%88%98%EC%97%B4LIS-%ED%8C%8C%EC%9D%B4%EC%8D%AC-Python)
