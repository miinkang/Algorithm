# %% [markdown]
# # 소수 구하기
# - source : [백준 1929](https://www.acmicpc.net/problem/1929)
# - 난이도 : 실버 III
# - 분류 : 구현, 문자열
#
# ## 문제
# - M이상 N이하의 소수를 모두 출력하는 프로그램을 작성하시오.
#
# ## 입력
# - 첫째 줄에 자연수 M과 N이 빈 칸을 사이에 두고 주어진다. (1 ≤ M ≤ N ≤ 1,000,000) M이상 N이하의 소수가 하나 이상 있는 입력만 주어진다.
#
# ## 출력
# - 한 줄에 하나씩, 증가하는 순서대로 소수를 출력한다.
#
# ![image-2.png](attachment:image-2.png)

# %%
m, n = map(int, input().split())

for i in range(m, n+1):
    flag = True
    for j in range(2, i):  # 1과 자기자신을 제외한 수로 나누기
        if i%j == 0:
            flag = False
            continue
    if flag:
        print(i)
# Out:
# 3 16
# 3
# 5
# 7
# 11
# 13

# %% [markdown]
# **시간초과!**
# ![image.png](attachment:image.png)

# %% [markdown]
# - 1,000,000 까지 반복하며 나누기 때문...
# - 약수는 대칭이기 때문에 **제곱근**까지만 계산해보면 된다.
#
# **또 시간초과!**
# - 조건에 break가 아닌 continue를 해서 더 반복 횟수가 많았던 것이 문제였다.
#
# **break & continue**
# - break : 해당 조건이 충족될 경우 반복문 탈출
# - continue : 해당 조건이 충족될 경우만 제외

# %%
import sys
m, n = map(int, sys.stdin.readline().split())

for i in range(m, n+1):
    if i == 1:
        continue
    flag = True
    for j in range(2, int(i**0.5) +1):  # 제곱근까지 나누어보기 
        if i%j == 0:
            flag = False
            break
    if flag:
        print(i)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# #### break, continue 차이를 정확하게 숙지할 수 있었다.
# - 시간초과를 해결하는 것이 관건이었던 문제
